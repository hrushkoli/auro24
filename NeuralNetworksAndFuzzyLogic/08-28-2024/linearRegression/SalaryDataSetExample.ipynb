# %% [markdown]
# # 1. Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing

# %% [markdown]
# # 2. Reading Data

# %%
salary = pd.read_csv("salary_dataset.csv")
#salary.drop(['index'],axis=1,inplace=True)

# %%
plt.figure(figsize=(16,10))
ax = sns.heatmap(salary.corr(),annot=True)
plt.show()

# %%
sns.regplot(data=salary, x= salary['YearsExperience'], y= salary['Salary'])
plt.show()

# %%
X=salary[['YearsExperience']]
Y=salary[['Salary']]
x_train, x_test, y_train , y_test = train_test_split(X,Y,test_size=0.2)

# %%
clf = LinearRegression()

# %%
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
clf.score(x_test,y_test)

predict = clf.predict(x_test)
predict
# Out:
# array([[ 63810.18521002],
#        [ 53133.09162623],
#        [125931.4569702 ],
#        [ 61868.89546751],
#        [ 92929.5313476 ],
#        [ 36632.12881494]])

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

import math
math.sqrt(mean_squared_error(predict,y_test))
# Out:
# 6232.117404155639

# %%
mean_squared_error(predict,y_test)
