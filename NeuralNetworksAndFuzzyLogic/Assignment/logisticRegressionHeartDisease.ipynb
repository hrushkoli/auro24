# %% [markdown]
# # 1. Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing

# %% [markdown]
# # 2. Reading Data

# %%
heartDiseaseData = pd.read_csv("heart_disease_classification.csv")
heartDiseaseData.head()
# Out:
#    Age     Sex  ChestPainType  RestingBP  cholesterol   FastingBS  \
# 0   63    male              3        145           233          1
# 1   37    male              2        130           250          0
# 2   41  female              1        130           204          0
# 3   56    male              1        120           236          0
# 4   57  female              0        120           354          0
#
#    Resting electrocardiographic  MaxHR  ExerciseAngina  Oldpeak  \
# 0                             0    150               0      2.3
# 1                             1    187               0      3.5
# 2                             0    172               0      1.4
# 3                             1    178               0      0.8
# 4                             1    163               1      0.6
#
#    slope of the peak  MajorVessels  Thalassemia   HeartDisease
# 0                  0             0             1             1
# 1                  0             0             2             1
# 2                  2             0             2             1
# 3                  2             0             2             1
# 4                  2             0             2             1

# %% [markdown]
# # 3. Encoding Sex data from "male", "female" to 1 &

# %%
label_encoder = preprocessing.LabelEncoder()
heartDiseaseData['Sex'] = label_encoder.fit_transform(heartDiseaseData['Sex'])
heartDiseaseData.head()
# Out:
#    Age  Sex  ChestPainType  RestingBP  cholesterol   FastingBS  \
# 0   63    1              3        145           233          1
# 1   37    1              2        130           250          0
# 2   41    0              1        130           204          0
# 3   56    1              1        120           236          0
# 4   57    0              0        120           354          0
#
#    Resting electrocardiographic  MaxHR  ExerciseAngina  Oldpeak  \
# 0                             0    150               0      2.3
# 1                             1    187               0      3.5
# 2                             0    172               0      1.4
# 3                             1    178               0      0.8
# 4                             1    163               1      0.6
#
#    slope of the peak  MajorVessels  Thalassemia   HeartDisease
# 0                  0             0             1             1
# 1                  0             0             2             1
# 2                  2             0             2             1
# 3                  2             0             2             1
# 4                  2             0             2             1

# %% [markdown]
# # 4. Creating a heatmap of the correlation matrix

# %%
plt.figure(figsize=(16,10))
ax = sns.heatmap(heartDiseaseData.corr(),annot=True)
plt.show()

# %% [markdown]
# # 5. Creating a regression plot of Thalassemia to know the link between Thalassemia and Heart Disease

# %%
sns.regplot(data=heartDiseaseData, x=heartDiseaseData['Thalassemia '], y=Y)
plt.show()

# %% [markdown]
# # 6. Splitting Data

# %%
X=heartDiseaseData[['Age','Sex','ChestPainType','RestingBP','cholesterol ','FastingBS','Resting electrocardiographic','MaxHR','ExerciseAngina','Oldpeak','slope of the peak','MajorVessels','Thalassemia ']]
Y=heartDiseaseData['HeartDisease']
x_train, x_test, y_train , y_test = train_test_split(X,Y,test_size=0.2)

# %% [markdown]
# # 7. Creating Linear Regression Model

# %%
clf = LinearRegression()

# %% [markdown]
# # 8. Training the model on the training data created previously

# %%
clf.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # 9. Predicting the values of heart disease using the test data

# %%
clf.score(x_train,y_train)

predict = clf.predict(x_test)
predict
# Out:
# array([ 0.23727426,  0.66035251,  0.08664074,  0.63767839,  0.57432005,
#         0.10486166,  0.64638157,  0.93000122,  0.71849402,  0.16925625,
#        -0.31424672,  0.64517727,  0.96333153,  0.20660514,  1.06333292,
#         1.02234578,  0.59789877, -0.14115404,  0.51156274,  1.13086249,
#         0.85690946,  0.01567001,  1.00131953,  0.2429905 ,  0.7361916 ,
#         0.3242543 , -0.15869592,  0.65177515,  0.40756448,  0.0657723 ,
#         0.87612429,  0.78328253,  0.91405384,  0.76733836,  0.77665283,
#         0.73982084,  0.08680908,  0.73045306,  0.438337  ,  1.0991209 ,
#         0.99398638, -0.00848804,  0.59504282,  0.20904821,  1.15460269,
#         0.84471319,  0.78514444,  0.75755669,  0.62559886,  0.56723263,
#        -0.15284294,  0.73253389,  0.7788039 ,  0.95362752,  0.24232543,
#         0.73499496,  0.36546439,  0.80472305,  0.82866155,  0.60450813,
#         0.0754572 ])

# %% [markdown]
# # 10. Finding the mean error between the test values and the test values

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

mean_squared_error(predict,y_test)
# Out:
# 0.10675802201673672

# %% [markdown]
# # 11. Finding the mean error between the test values and the predicted values

# %%
mean_squared_error(predict,y_test)
# Out:
# 0.10675802201673672
